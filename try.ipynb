# %%
from process import *
read_states()
# Out:
#          location_id  location_name     FIPS  cause_id  \
# 0                536       Illinois     17.0       560
# 1                536       Illinois     17.0       560
# 2                536       Illinois     17.0       560
# 3                536       Illinois     17.0       560
# 4                536       Illinois     17.0       560
# ...              ...            ...      ...       ...
# 1341475         3699  Weston County  56045.0       724
# 1341476         3699  Weston County  56045.0       724
# 1341477         3699  Weston County  56045.0       724
# 1341478         3699  Weston County  56045.0       724
# 1341479         3699  Weston County  56045.0       724
#
#                      cause_name  sex_id   sex          age_name  year_id  \
# 0         Alcohol use disorders       1  Male  Age-standardized     1980
# 1         Alcohol use disorders       1  Male  Age-standardized     1981
# 2         Alcohol use disorders       1  Male  Age-standardized     1982
# ...
